# %% [markdown]
# <a href="https://colab.research.google.com/github/varshithak3117/Python-basics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %%
name="varshitha"
year="2026"

print("Hello", name)
print(year)
# Out:
# Hello varshitha
# 2026

# %%
marks=int(input ("enter your marks"))
if marks>50:
   print("you are promoted")
else:
   print("come again next year")
# Out:
# enter your marks40
# come again next year

# %%
age=int(input("enter your age"))
if age >=18:
   print("you can vote")
else:
   print ("you can't vote")
# Out:
# enter your age18
# you can vote

# %%
A=int(input("enter the value of a"))
B=int(input("enter the value of b"))

print(A)
print(B)
print(A+B)
print(A-B)
# Out:
# enter the value of a10
# enter the value of b20
# 10
# 20
# 30
# -10

# %%
A=input("enter your name")
B=input("enter your age")
print("hello",A)
print("your age is",B)
# Out:
# enter your nameVarshitha
# enter your age18
# hello Varshitha
# your age is 18

# %%
a=10
b=5
sum=a+b
sub=a-b
mul=a*b
div=a/b
print("sum",sum)
print("sub",sub)
print("mul",mul)
print("div",div)
# Out:
# sum 15
# sub 5
# mul 50
# div 2.0

# %%
def greet():
    print("hello world")
greet()
# Out:
# hello world

# %%
print("varshitha")
# Out:
# varshitha

# %%
for i in range(1,7):
    print(2*i,end=" ")
print()
# Out:
# 2 4 6 8 10 12

# %%
def greet(name):
    print("Hello👋",name)
greet("varshitha")
greet("kumar")
# Out:
# Hello👋 varshitha
# Hello👋 kumar

# %%
def add(a,b):
    return a+b
result=add(5,3)
print(result)
# Out:
# 8
